# %% [markdown]
# ## Libraries

# %%
#libraries
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics # Import scikit-learn metrics module for accuracy, precision or recall calculation
from sklearn.model_selection import GridSearchCV
import random
import pprint
pp = pprint.PrettyPrinter(indent=4)


import os
import numpy as np
from sklearn import datasets
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sb

# %% [markdown]
# ### Importing pre-split data

# %% [markdown]
# ## 03 - Dataset

# %% [markdown]
# We have applied 4 methods of re-sampling in a separate python notebook within the main P1 repository. These methods are:
# * 1. NearMiss Under-sampling.
# * 2. SMOTE Over-sampling.
# * 3. SMOTEENN.
# * 4. SMOTETomek.
#
# From there, we produced 6 separate files for each re-sampling method; being:
# * X_train,
# * X_test,
# * X_val,
# * Y_train,
# * Y_test,
# * Y_val.
#
# Below, we import these files.

# %%
# Original (only split without sampling) 
X_train_original = pd.read_csv(r'X_train_original.csv')
X_test_original = pd.read_csv(r'X_test_original.csv')
X_val_original = pd.read_csv(r'X_val_original.csv')
y_train_original = pd.read_csv(r'y_train_original.csv')
y_test_original = pd.read_csv(r'y_test_original.csv')
y_val_original = pd.read_csv(r'y_val_original.csv')

# Near-miss undersampling datasets:
X_train_NM2 = pd.read_csv(r'X_train_NM2.csv')
X_test_NM2 = pd.read_csv(r'X_test_NM2.csv')
X_val_NM2 = pd.read_csv(r'X_val_NM2.csv')
y_train_NM2 = pd.read_csv(r'y_train_NM2.csv')
y_test_NM2 = pd.read_csv(r'y_test_NM2.csv')
y_val_NM2 = pd.read_csv(r'y_val_NM2.csv')

# SMOTE over-sampling datasets:
X_train_SMOTE = pd.read_csv(r'X_train_SMOTE.csv')
X_test_SMOTE = pd.read_csv(r'X_test_SMOTE.csv')
X_val_SMOTE = pd.read_csv(r'X_val_SMOTE.csv')
y_train_SMOTE = pd.read_csv(r'y_train_SMOTE.csv')
y_test_SMOTE = pd.read_csv(r'y_test_SMOTE.csv')
y_val_SMOTE = pd.read_csv(r'y_val_SMOTE.csv')

# SMOTEENN over-sampling datasets:
X_train_SMOTEENN = pd.read_csv(r'X_train_SMOTEENN.csv')
X_test_SMOTEENN = pd.read_csv(r'X_test_SMOTEENN.csv')
X_val_SMOTEENN = pd.read_csv(r'X_val_SMOTEENN.csv')
y_train_SMOTEENN = pd.read_csv(r'y_train_SMOTEENN.csv')
y_test_SMOTEENN = pd.read_csv(r'y_test_SMOTEENN.csv')
y_val_SMOTEENN = pd.read_csv(r'y_val_SMOTEENN.csv')

# SMOTETomek over-sampling datasets:
X_train_SMOTETomek = pd.read_csv(r'X_train_SMOTETomek.csv')
X_test_SMOTETomek = pd.read_csv(r'X_test_SMOTETomek.csv')
X_val_SMOTETomek = pd.read_csv(r'X_val_SMOTETomek.csv')
y_train_SMOTETomek = pd.read_csv(r'y_train_SMOTETomek.csv')
y_test_SMOTETomek = pd.read_csv(r'y_test_SMOTETomek.csv')
y_val_SMOTETomek = pd.read_csv(r'y_val_SMOTETomek.csv')

# %% [markdown]
# ### Create GridSearch CV parameters and model

# %%
tree_para = {'criterion':['gini','entropy']
             ,'max_depth':[4,5,6,7,8,9,10,11,12,15,20,30]
            ,'min_samples_leaf':[1,2,3,4,5,10]}
# splits

clf = GridSearchCV(DecisionTreeClassifier(), tree_para, cv=5)

# %% [markdown]
# ### 00 - Original dataset

# %%
absorbance_cols = [col for col in X_train_original.columns if 'fa' in col]
#print(list(df.columns))
print(absorbance_cols)
print(len(absorbance_cols))
# Out:
# ['fa226', 'fa257', 'fa280', 'fa297', 'fa324', 'fa343', 'fa363', 'fa385', 'fa408', 'fa432', 'fa458', 'fa471', 'fa500', 'fa514', 'fa545', 'fa561', 'fa577', 'fa594', 'fa629', 'fa648', 'fa667', 'fa686', 'fa707', 'fa727', 'fa749', 'fa771', 'fa793', 'fa816', 'fa840', 'fa865', 'fa890', 'fa917', 'fa943', 'fa971', 'fa1000', 'fa1029', 'fa1059', 'fa1090', 'fa1122', 'fa1155', 'fa1189', 'fa1224', 'fa1259', 'fa1296', 'fa1334', 'fa1373', 'fa1414', 'fa1455', 'fa1498', 'fa1542', 'fa1587', 'fa1633', 'fa1681', 'fa1731', 'fa1781', 'fa1834', 'fa1887', 'fa1943', 'fa2000', 'fa2058', 'fa2118', 'fa2181', 'fa2244', 'fa2310', 'fa2378', 'fa2448', 'fa2519', 'fa2593', 'fa2669', 'fa2747', 'fa2828', 'fa2911', 'fa2996', 'fa3084', 'fa3174', 'fa3267', 'fa3363', 'fa3462', 'fa3563', 'fa3668', 'fa3775', 'fa3886', 'fa4000', 'fa4117', 'fa4237', 'fa4362', 'fa4489', 'fa4621', 'fa4756', 'fa4896', 'fa5039', 'fa5187', 'fa5339', 'fa5495', 'fa5656', 'fa5822', 'fa5993', 'fa6168', 'fa6349', 'fa6535', 'fa6727', 'fa6924', 'fa7127', 'fa7336', 'fa7550', 'fa7772', 'fa8000']
# 107

# %%
# changed to val
X_train_absorbance = X_train_original.iloc[:, X_train_original.columns.isin(absorbance_cols)]

X_test_absorbance = X_val_original.iloc[:, X_val_original.columns.isin(absorbance_cols)]

len(X_test_absorbance)
# Out:
# 39

# %%
feature_cols = list(X_train_absorbance.columns.values.tolist())

len(feature_cols)
# Out:
# 107

# %% [markdown]
# Feature Selection
# Here, you need to divide given columns into two types of variables dependent(or target variable) and independent variable(or feature variables).

# %% [markdown]
# #### Building Decision Tree Model
# Let's create a Decision Tree Model using Scikit-learn.

# %%
random.seed(21520699)

# Train Decision Tree Classifer
clf = clf.fit(X_train_absorbance, y_train_original)

#Predict the response for test dataset
y_train = clf.predict(X_train_absorbance)
y_pred = clf.predict(X_test_absorbance)

# %% [markdown]
# #### Params in best model determined by GridSearchCV

# %%
random.seed(21520699)
# return best parameters as calculated by GridSearchCV
clf.best_estimator_.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 7,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# #### Evaluating Model
# Let's estimate, how accurately the classifier or model can predict the type of cultivars. Accuracy can be computed by comparing actual test set values and predicted values.

# %%
# Model Accuracy, how often is the classifier correct?
# train accuracy
print("Accuracy:", metrics.accuracy_score(y_train_original, y_train))

# test accuracy
print("Accuracy:", metrics.accuracy_score(y_val_original, y_pred))

## RECALL

# Model recall
# train dataset
print("Recall:", metrics.recall_score(y_train_original, y_train))

# val dataset
print("Recall:", metrics.recall_score(y_val_original, y_pred))
# Out:
# Accuracy: 0.9539473684210527
# Accuracy: 0.9230769230769231
# Recall: 0.6818181818181818
# Recall: 0.7777777777777778

# %% [markdown]
# #### Determine best features

# %%
# Extracting the importances by sklearn 
importances_sk = clf.best_estimator_.feature_importances_

# Creating a dataframe with the feature importance by sklearn
feature_importance_sk = {}
for i, feature in enumerate(feature_cols):
    feature_importance_sk[feature] = round(importances_sk[i], 3)

#pp.pprint(f"Feature importance by sklearn: {feature_importance_sk}")

non_zero = {x:y for x,y in feature_importance_sk.items() if y!=0}
sorted_dict = dict(sorted(non_zero.items(), key=lambda item: item[1],reverse=True))


for k, v in sorted_dict.items():
    print (k, '-->', v)
#pprint.pprint(f"Feature importance by sklearn: {sorted_dict}")
# Out:
# fa1296 --> 0.747
# fa4756 --> 0.126
# fa4237 --> 0.06
# fa1155 --> 0.034
# fa5993 --> 0.016
# fa594 --> 0.01
# fa4117 --> 0.007

# %% [markdown]
# #### Visualise Decision Tree
# Can use Scikit-learn's export_graphviz function for display the tree within a Jupyter notebook.
#
# Need to install graphviz and pydotplus:
# * conda install graphviz
# * conda install -c conda-forge pydotplus

# %%
from sklearn.tree import export_graphviz
from six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()

export_graphviz(clf.best_estimator_
                ,out_file=dot_data
                ,filled=True
                ,rounded=True
                ,special_characters=True
                ,feature_names = feature_cols
                ,class_names=['0','1'])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
#graph.write_png('freqs_only_tree.png')
Image(graph.create_png())

# still fa280 whether val as test or test as test.

# %% [markdown]
# ### 01 - NearMiss Under-sampling

# %%
absorbance_cols = [col for col in X_train_NM2.columns if 'fa' in col]
#print(list(df.columns))
print(absorbance_cols)
print(len(absorbance_cols))
# Out:
# ['fa226', 'fa257', 'fa280', 'fa297', 'fa324', 'fa343', 'fa363', 'fa385', 'fa408', 'fa432', 'fa458', 'fa471', 'fa500', 'fa514', 'fa545', 'fa561', 'fa577', 'fa594', 'fa629', 'fa648', 'fa667', 'fa686', 'fa707', 'fa727', 'fa749', 'fa771', 'fa793', 'fa816', 'fa840', 'fa865', 'fa890', 'fa917', 'fa943', 'fa971', 'fa1000', 'fa1029', 'fa1059', 'fa1090', 'fa1122', 'fa1155', 'fa1189', 'fa1224', 'fa1259', 'fa1296', 'fa1334', 'fa1373', 'fa1414', 'fa1455', 'fa1498', 'fa1542', 'fa1587', 'fa1633', 'fa1681', 'fa1731', 'fa1781', 'fa1834', 'fa1887', 'fa1943', 'fa2000', 'fa2058', 'fa2118', 'fa2181', 'fa2244', 'fa2310', 'fa2378', 'fa2448', 'fa2519', 'fa2593', 'fa2669', 'fa2747', 'fa2828', 'fa2911', 'fa2996', 'fa3084', 'fa3174', 'fa3267', 'fa3363', 'fa3462', 'fa3563', 'fa3668', 'fa3775', 'fa3886', 'fa4000', 'fa4117', 'fa4237', 'fa4362', 'fa4489', 'fa4621', 'fa4756', 'fa4896', 'fa5039', 'fa5187', 'fa5339', 'fa5495', 'fa5656', 'fa5822', 'fa5993', 'fa6168', 'fa6349', 'fa6535', 'fa6727', 'fa6924', 'fa7127', 'fa7336', 'fa7550', 'fa7772', 'fa8000']
# 107

# %%
# changed to val
X_train_absorbance = X_train_NM2.iloc[:, X_train_NM2.columns.isin(absorbance_cols)]

X_test_absorbance = X_val_NM2.iloc[:, X_val_NM2.columns.isin(absorbance_cols)]

len(X_test_absorbance)
# Out:
# 39

# %%
feature_cols = list(X_train_absorbance.columns.values.tolist())

len(feature_cols)
# Out:
# 107

# %% [markdown]
# Feature Selection
# Here, you need to divide given columns into two types of variables dependent(or target variable) and independent variable(or feature variables).

# %% [markdown]
# #### Building Decision Tree Model
# Let's create a Decision Tree Model using Scikit-learn.

# %%
random.seed(21520699)

# Train Decision Tree Classifer
clf = clf.fit(X_train_absorbance, y_train_NM2)

#Predict the response for test dataset
y_train = clf.predict(X_train_absorbance)

y_pred = clf.predict(X_test_absorbance)

# %% [markdown]
# #### Params in best model determined by GridSearchCV

# %%
# return best parameters as calculated by GridSearchCV
clf.best_estimator_.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 30,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# #### Evaluating Model
# Let's estimate, how accurately the classifier or model can predict the type of cultivars. Accuracy can be computed by comparing actual test set values and predicted values.

# %%
# ACCURACY

#train:
print("Accuracy:", metrics.accuracy_score(y_train_NM2, y_train))

#val:
print("Accuracy:", metrics.accuracy_score(y_val_NM2, y_pred))


# RECALL
#train:
print("Recall:", metrics.recall_score(y_train_NM2, y_train))

#val:
print("Recall:", metrics.recall_score(y_val_NM2, y_pred))
# Out:
# Accuracy: 1.0
# Accuracy: 0.5897435897435898
# Recall: 1.0
# Recall: 0.6666666666666666

# %% [markdown]
# #### Determine best features

# %%
# Extracting the importances by sklearn 
importances_sk = clf.best_estimator_.feature_importances_

# Creating a dataframe with the feature importance by sklearn
feature_importance_sk = {}
for i, feature in enumerate(feature_cols):
    feature_importance_sk[feature] = round(importances_sk[i], 3)

#pp.pprint(f"Feature importance by sklearn: {feature_importance_sk}")

non_zero = {x:y for x,y in feature_importance_sk.items() if y!=0}
sorted_dict = dict(sorted(non_zero.items(), key=lambda item: item[1],reverse=True))


for k, v in sorted_dict.items():
    print (k, '-->', v)
#pprint.pprint(f"Feature importance by sklearn: {sorted_dict}")
# Out:
# fa280 --> 0.49
# fa3775 --> 0.186
# fa3563 --> 0.086
# fa226 --> 0.079
# fa471 --> 0.073
# fa727 --> 0.045
# fa2244 --> 0.041

# %% [markdown]
# #### Visualise Decision Tree
# Can use Scikit-learn's export_graphviz function for display the tree within a Jupyter notebook.
#
# Need to install graphviz and pydotplus:
# * conda install graphviz
# * conda install -c conda-forge pydotplus

# %%
from sklearn.tree import export_graphviz
from six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()

export_graphviz(clf.best_estimator_
                ,out_file=dot_data
                ,filled=True
                ,rounded=True
                ,special_characters=True
                ,feature_names = feature_cols
                ,class_names=['0','1'])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
#graph.write_png('freqs_only_tree.png')
Image(graph.create_png())

# still fa280 whether val as test or test as test.

# %% [markdown]
# ### 01 - SMOTE over-sampling

# %%
absorbance_cols = [col for col in X_train_SMOTE.columns if 'fa' in col]
#print(list(df.columns))
print(len(absorbance_cols)) #should be 107 absorbance cols
# Out:
# 107

# %%
X_train_absorbance = X_train_SMOTE.iloc[:, X_train_SMOTE.columns.isin(absorbance_cols)]

X_test_absorbance = X_val_SMOTE.iloc[:, X_val_SMOTE.columns.isin(absorbance_cols)]

# %%
feature_cols = list(X_train_absorbance.columns.values.tolist())

len(feature_cols)
# Out:
# 107

# %% [markdown]
# Feature Selection
# Here, you need to divide given columns into two types of variables dependent(or target variable) and independent variable(or feature variables).

# %% [markdown]
# #### Building Decision Tree Model
# Let's create a Decision Tree Model using Scikit-learn.

# %%
random.seed(21520699)

# Train Decision Tree Classifer
clf = clf.fit(X_train_absorbance, y_train_SMOTE)

#Predict the response for test dataset
y_train = clf.predict(X_train_absorbance)
y_pred = clf.predict(X_test_absorbance)

# %% [markdown]
# #### Params in best model determined by GridSearchCV

# %%
# return best parameters as calculated by GridSearchCV
clf.best_estimator_.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': 4,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# #### Evaluating Model
# Let's estimate, how accurately the classifier or model can predict the type of cultivars. Accuracy can be computed by comparing actual test set values and predicted values.

# %%
# ACCURACY

# train
print("Accuracy:", metrics.accuracy_score(y_train_SMOTE, y_train))

# val
print("Accuracy:", metrics.accuracy_score(y_val_SMOTE, y_pred))


# RECALL
# train
print("Recall:", metrics.recall_score(y_train_SMOTE, y_train))

# val
print("Recall:", metrics.recall_score(y_val_SMOTE, y_pred))
# Out:
# Accuracy: 0.9692307692307692
# Accuracy: 0.9487179487179487
# Recall: 0.9461538461538461
# Recall: 0.8888888888888888

# %% [markdown]
# #### Determine best features

# %%
# Extracting the importances by sklearn 
importances_sk = clf.best_estimator_.feature_importances_

# Creating a dataframe with the feature importance by sklearn
feature_importance_sk = {}
for i, feature in enumerate(feature_cols):
    feature_importance_sk[feature] = round(importances_sk[i], 3)

#pp.pprint(f"Feature importance by sklearn: {feature_importance_sk}")

non_zero = {x:y for x,y in feature_importance_sk.items() if y!=0}
sorted_dict = dict(sorted(non_zero.items(), key=lambda item: item[1],reverse=True))


for k, v in sorted_dict.items():
    print (k, '-->', v)
#pprint.pprint(f"Feature importance by sklearn: {sorted_dict}")
# Out:
# fa1296 --> 0.503
# fa1155 --> 0.108
# fa4117 --> 0.1
# fa1943 --> 0.089
# fa2519 --> 0.062
# fa3363 --> 0.058
# fa280 --> 0.05
# fa1455 --> 0.031

# %% [markdown]
# #### Visualise Decision Tree
# Can use Scikit-learn's export_graphviz function for display the tree within a Jupyter notebook.
#
# Need to install graphviz and pydotplus:
# * conda install graphviz
# * conda install -c conda-forge pydotplus

# %%
from sklearn.tree import export_graphviz
from six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()

export_graphviz(clf.best_estimator_
                ,out_file=dot_data
                ,filled=True
                ,rounded=True
                ,special_characters=True
                ,feature_names = feature_cols
                ,class_names=['0','1'])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('freqs_only_tree.png')
Image(graph.create_png())

# %% [markdown]
# ### 01 - SMOTEENN over-sampling

# %%
absorbance_cols = [col for col in X_train_SMOTEENN.columns if 'fa' in col]
#print(list(df.columns))
print(len(absorbance_cols)) #107
# Out:
# 107

# %%
X_train_absorbance = X_train_SMOTEENN.iloc[:, X_train_SMOTEENN.columns.isin(absorbance_cols)]

X_test_absorbance = X_val_SMOTEENN.iloc[:, X_val_SMOTEENN.columns.isin(absorbance_cols)]

# %%
feature_cols = list(X_train_absorbance.columns.values.tolist())

len(feature_cols)
# Out:
# 107

# %% [markdown]
# Feature Selection
# Here, you need to divide given columns into two types of variables dependent(or target variable) and independent variable(or feature variables).

# %% [markdown]
# #### Building Decision Tree Model
# Let's create a Decision Tree Model using Scikit-learn.

# %%
random.seed(21520699)

# Train Decision Tree Classifer

clf = clf.fit(X_train_absorbance,y_train_SMOTEENN)

#Predict the response for test dataset
y_train = clf.predict(X_train_absorbance)
y_pred = clf.predict(X_test_absorbance)

# %% [markdown]
# #### Params in best model determined by GridSearchCV

# %%
# return best parameters as calculated by GridSearchCV
clf.best_estimator_.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# #### Evaluating Model
# Let's estimate, how accurately the classifier or model can predict the type of cultivars. Accuracy can be computed by comparing actual test set values and predicted values.

# %%
# ACCURACY

# train
print("Accuracy:", metrics.accuracy_score(y_train_SMOTEENN, y_train))

# val
print("Accuracy:", metrics.accuracy_score(y_val_SMOTEENN, y_pred))

# RECALL

# train
print("Recall:", metrics.recall_score(y_train_SMOTEENN, y_train))

# val
print("Recall:", metrics.recall_score(y_val_SMOTEENN, y_pred))
# Out:
# Accuracy: 0.9862385321100917
# Accuracy: 0.8717948717948718
# Recall: 0.9752066115702479
# Recall: 0.7777777777777778

# %% [markdown]
# #### Determine best features

# %%
# Extracting the importances by sklearn 
importances_sk = clf.best_estimator_.feature_importances_

# Creating a dataframe with the feature importance by sklearn
feature_importance_sk = {}
for i, feature in enumerate(feature_cols):
    feature_importance_sk[feature] = round(importances_sk[i], 3)

#pp.pprint(f"Feature importance by sklearn: {feature_importance_sk}")

non_zero = {x:y for x,y in feature_importance_sk.items() if y!=0}
sorted_dict = dict(sorted(non_zero.items(), key=lambda item: item[1],reverse=True))


for k, v in sorted_dict.items():
    print (k, '-->', v)
#pprint.pprint(f"Feature importance by sklearn: {sorted_dict}")
# Out:
# fa1155 --> 0.635
# fa4117 --> 0.095
# fa6535 --> 0.085
# fa1887 --> 0.054
# fa1542 --> 0.049
# fa816 --> 0.036
# fa4489 --> 0.022
# fa629 --> 0.017
# fa343 --> 0.006
# fa4362 --> 0.002

# %% [markdown]
# #### Visualise Decision Tree
# Can use Scikit-learn's export_graphviz function for display the tree within a Jupyter notebook.
#
# Need to install graphviz and pydotplus:
# * conda install graphviz
# * conda install -c conda-forge pydotplus

# %%
from sklearn.tree import export_graphviz
from six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()

export_graphviz(clf.best_estimator_
                ,out_file=dot_data
                ,filled=True
                ,rounded=True
                ,special_characters=True
                ,feature_names = feature_cols
                ,class_names=['0','1'])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('freqs_only_tree.png')
Image(graph.create_png())

# fa1189 no change.

# %% [markdown]
# ### 01 - SMOTETomek over-sampling

# %%
absorbance_cols = [col for col in X_train_SMOTETomek.columns if 'fa' in col]
#print(list(df.columns))
print(len(absorbance_cols)) # should be 107
# Out:
# 107

# %%
X_train_absorbance = X_train_SMOTETomek.iloc[:, X_train_SMOTETomek.columns.isin(absorbance_cols)]

X_test_absorbance = X_val_SMOTETomek.iloc[:, X_val_SMOTETomek.columns.isin(absorbance_cols)]

# %%
feature_cols = list(X_train_absorbance.columns.values.tolist())

len(feature_cols)
# Out:
# 107

# %% [markdown]
# Feature Selection
# Here, you need to divide given columns into two types of variables dependent(or target variable) and independent variable(or feature variables).

# %% [markdown]
# #### Building Decision Tree Model
# Let's create a Decision Tree Model using Scikit-learn.

# %%
random.seed(21520699)
# Train Decision Tree Classifer
clf = clf.fit(X_train_absorbance,y_train_SMOTETomek)

#Predict the response for test dataset
y_train = clf.predict(X_train_absorbance)
y_pred = clf.predict(X_test_absorbance)

# %% [markdown]
# #### Params in best model determined by GridSearchCV

# %%
# return best parameters as calculated by GridSearchCV
clf.best_estimator_.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %% [markdown]
# #### Evaluating Model
# Let's estimate, how accurately the classifier or model can predict the type of cultivars. Accuracy can be computed by comparing actual test set values and predicted values.

# %%
# ACCURACY

# train accuracy
print("Accuracy:", metrics.accuracy_score(y_train_SMOTETomek, y_train))

# val accuracy
print("Accuracy:", metrics.accuracy_score(y_val_SMOTETomek, y_pred))

# RECALL

# train recall
print("Recall:", metrics.recall_score(y_train_SMOTETomek, y_train))

# val recall
print("Recall:", metrics.recall_score(y_val_SMOTETomek, y_pred))
# Out:
# Accuracy: 0.9763779527559056
# Accuracy: 0.8974358974358975
# Recall: 0.952755905511811
# Recall: 0.7777777777777778

# %% [markdown]
# #### Determine best features

# %%
# Extracting the importances by sklearn 
importances_sk = clf.best_estimator_.feature_importances_

# Creating a dataframe with the feature importance by sklearn
feature_importance_sk = {}
for i, feature in enumerate(feature_cols):
    feature_importance_sk[feature] = round(importances_sk[i], 3)

#pp.pprint(f"Feature importance by sklearn: {feature_importance_sk}")

non_zero = {x:y for x,y in feature_importance_sk.items() if y!=0}
sorted_dict = dict(sorted(non_zero.items(), key=lambda item: item[1],reverse=True))


for k, v in sorted_dict.items():
    print (k, '-->', v)
#pprint.pprint(f"Feature importance by sklearn: {sorted_dict}")
# Out:
# fa1090 --> 0.606
# fa4756 --> 0.091
# fa4117 --> 0.087
# fa1887 --> 0.082
# fa1155 --> 0.066
# fa840 --> 0.027
# fa458 --> 0.017
# fa3886 --> 0.017
# fa1029 --> 0.006

# %% [markdown]
# #### Visualise Decision Tree
# Can use Scikit-learn's export_graphviz function for display the tree within a Jupyter notebook.
#
# Need to install graphviz and pydotplus:
# * conda install graphviz
# * conda install -c conda-forge pydotplus

# %%
from sklearn.tree import export_graphviz
from six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()

export_graphviz(clf.best_estimator_
                ,out_file=dot_data
                ,filled=True
                ,rounded=True
                ,special_characters=True
                ,feature_names = feature_cols
                ,class_names=['0','1'])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('freqs_only_tree.png')
Image(graph.create_png())

# fa1090 as both.
